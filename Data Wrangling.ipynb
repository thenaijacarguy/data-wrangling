# %% [markdown]
# Data Gathering, Data Assessing, Data Cleaning

# %%
import pandas as pd

# %%
df = pd.read_excel('Titanic Data.xlsx')

# %%
df.loc[3,'Cabin']
# Out:
# 'C123'

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# Visual assessment, Programmatic assessment

# %% [markdown]
# - change the column names to lowercase
# - make the Pclass column more descriptive
# - split the name column into last name and other names
# - delete the ticket and cabin columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Name         891 non-null    object
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Survived     891 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.836071   14.526497    1.102743    0.806057
# min       1.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare    Survived
# count  891.000000  891.000000
# mean    32.204208    0.383838
# std     49.693429    0.486592
# min      0.000000    0.000000
# 25%      7.910400    0.000000
# 50%     14.454200    0.000000
# 75%     31.000000    1.000000
# max    512.329200    1.000000

# %% [markdown]
# - check the passenger whose age is 0.42

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df.columns= df.columns.str.lower()

# %%
df.head(1)
# Out:
#    passengerid  pclass                     name   sex   age  sibsp  parch  \
# 0            1       3  Braund, Mr. Owen Harris  male  22.0      1      0
#
#       ticket  fare cabin embarked  survived
# 0  A/5 21171  7.25   NaN        S         0

# %%
df.rename(columns = {'pclass':'passenger_class'}, inplace = True)

# %%
df
# Out:
#      passengerid  passenger_class  \
# 0              1                3
# 1              2                1
# 2              3                3
# 3              4                1
# 4              5                3
# ..           ...              ...
# 886          887                2
# 887          888                1
# 888          889                3
# 889          890                1
# 890          891                3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
class_mapping = {1: 'first class', 2: 'second class', 3: 'third class'}

# %%
df['passenger_class'] = df['passenger_class'].map(class_mapping)

# %%
df
# Out:
#      passengerid passenger_class  \
# 0              1     third class
# 1              2     first class
# 2              3     third class
# 3              4     first class
# 4              5     third class
# ..           ...             ...
# 886          887    second class
# 887          888     first class
# 888          889     third class
# 889          890     first class
# 890          891     third class
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['other_names'] = df['name'].str.split(',', expand=True)[1]
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 886                                    Rev. Juozas
# 887                           Miss. Margaret Edith
# 888                 Miss. Catherine Helen "Carrie"
# 889                                Mr. Karl Howell
# 890                                    Mr. Patrick
# Name: 1, Length: 891, dtype: object

# %%
df
# Out:
#      passengerid passenger_class  \
# 0              1     third class
# 1              2     first class
# 2              3     third class
# 3              4     first class
# 4              5     third class
# ..           ...             ...
# 886          887    second class
# 887          888     first class
# 888          889     third class
# 889          890     first class
# 890          891     third class
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      passengerid passenger_class     sex   age  sibsp  parch  \
# 0              1     third class    male  22.0      1      0
# 1              2     first class  female  38.0      1      0
# 2              3     third class  female  26.0      0      0
# 3              4     first class  female  35.0      1      0
# 4              5     third class    male  35.0      0      0
# ..           ...             ...     ...   ...    ...    ...
# 886          887    second class    male  27.0      0      0
# 887          888     first class  female  19.0      0      0
# 888          889     third class  female   NaN      1      2
# 889          890     first class    male  26.0      0      0
# 890          891     third class    male  32.0      0      0
#
#                ticket     fare cabin embarked  survived  last_name  \
# 0           A/5 21171   7.2500   NaN        S         0     Braund
# 1            PC 17599  71.2833   C85        C         1    Cumings
# ...

# %%
df.pop('ticket')
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: ticket, Length: 891, dtype: object

# %%
del df['parch']

# %%
df
# Out:
#      passengerid passenger_class     sex   age  sibsp     fare embarked  \
# 0              1     third class    male  22.0      1   7.2500        S
# 1              2     first class  female  38.0      1  71.2833        C
# 2              3     third class  female  26.0      0   7.9250        S
# 3              4     first class  female  35.0      1  53.1000        S
# 4              5     third class    male  35.0      0   8.0500        S
# ..           ...             ...     ...   ...    ...      ...      ...
# 886          887    second class    male  27.0      0  13.0000        S
# 887          888     first class  female  19.0      0  30.0000        S
# 888          889     third class  female   NaN      1  23.4500        S
# 889          890     first class    male  26.0      0  30.0000        C
# 890          891     third class    male  32.0      0   7.7500        Q
#
#      survived  last_name                                  other_names
# ...

# %%
df['survived'].replace(1,'Survived')

# %%
df
# Out:
#      passengerid passenger_class     sex   age  sibsp     fare embarked  \
# 0              1     third class    male  22.0      1   7.2500        S
# 1              2     first class  female  38.0      1  71.2833        C
# 2              3     third class  female  26.0      0   7.9250        S
# 3              4     first class  female  35.0      1  53.1000        S
# 4              5     third class    male  35.0      0   8.0500        S
# ..           ...             ...     ...   ...    ...      ...      ...
# 886          887    second class    male  27.0      0  13.0000        S
# 887          888     first class  female  19.0      0  30.0000        S
# 888          889     third class  female   NaN      1  23.4500        S
# 889          890     first class    male  26.0      0  30.0000        C
# 890          891     third class    male  32.0      0   7.7500        Q
#
#      survived  last_name                                  other_names
# ...

# %%
df2 = pd.read_csv('~/Downloads/assignment.csv')

# %%
df2
# Out:
#      Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# ...

# %%
import seaborn as sb

# %%
sb.countplot(data=df2, y='Country');
